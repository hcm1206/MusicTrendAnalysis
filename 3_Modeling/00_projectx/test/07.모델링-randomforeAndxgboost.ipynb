# %%
# # final_total_data.csv 파일을 불러와서 'date' 컬럼을 datetime 형식으로 변환 후, X_data에 추가하는 코드 작성
# import pandas as pd

# # final_total_data.csv 파일 불러오기
# file_path = '../../data/final_total_data.csv'
# final_data = pd.read_csv(file_path)
# final_data['date'] = pd.to_datetime(final_data['date'])



# X_data = pd.read_csv('../../data/X_data.csv', index_col = 0)
# y_data = pd.read_csv('../../data/y_data.csv', index_col = 0)
# X_data['date'] = final_data['date']

# # 'date' 컬럼을 datetime 형식으로 변환
# X_data['New_Rank'] = X_data['New_Rank'].astype(int)

# # 결과 확인
# X_data.head()

import pandas as pd

# final_total_data.csv 파일 불러오기
file_path = 'testsin.csv'
data = pd.read_csv(file_path)


data.tail().T
# Out:
#                                   9838                             9839  \
# Unnamed: 0                        9838                             9839
# date                        2024-09-08                       2024-09-08
# Rank                               195                              196
# New_Artist                          싸이                               이지
# Title                 어땠을까 (Feat. 박정현)                              응급실
# Production            YG Entertainment                           엠디엠이엔티
# Runtime                       0.947076                         0.448018
# Genre                            가요/댄스                          OST/드라마
# Weekly Views                 -0.201869                        -1.011885
# n_score                       0.155657                         0.484755
# g_score                           0.62                             0.96
# ky_chart_on                          0                                0
# ...

# %%
# sin_day 열에서 중복되지 않는 값만 선택
unique_sin_day = data.drop_duplicates(subset=['sin_day'])

# date 열 뒤에 unique_sin_day 값을 출력
result = data[['date', 'sin_day']].drop_duplicates(subset=['sin_day'])

# 결과 출력
print(result)
# Out:
#             date       sin_day
# 0     2023-09-24 -9.510565e-01
# 193   2023-10-01  2.079117e-01
# 383   2023-10-08  9.945219e-01
# 572   2023-10-15  5.665539e-16
# 762   2023-10-22 -9.945219e-01
# 955   2023-10-29 -2.079117e-01
# 1148  2023-11-05  8.660254e-01
# 1342  2023-11-12  5.877853e-01
# 1532  2023-11-19 -7.431448e-01
# 1911  2023-12-03  5.877853e-01
# 2099  2023-12-10  8.660254e-01
# 2285  2023-12-17 -4.067366e-01
# 2649  2023-12-31  2.079117e-01
# 2839  2024-01-07  9.945219e-01
# 3433  2024-01-28 -4.067366e-01
# 3629  2024-02-04  7.431448e-01
# 3826  2024-02-11  7.431448e-01
# 4022  2024-02-18 -5.877853e-01
# 4217  2024-02-25 -8.660254e-01
# 6908  2024-06-02  4.067366e-01
# 7107  2024-06-09  9.510565e-01
# 7305  2024-06-16 -2.079117e-01
# 7502  2024-06-23 -9.945219e-01
# 7699  2024-06-30 -1.133108e-15
