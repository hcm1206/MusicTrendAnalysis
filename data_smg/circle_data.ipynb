# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('circle_chart_data(20240926).csv')
df2 = pd.read_csv(r'C:\Users\user\Desktop\smg\daegeun\Transformed_Data_with_New_Artist.csv')

# %%
df1.head()
# Out:
#          date  Rank                             Title  \
# 0  2023-09-24     1                          Love Lee
# 1  2023-09-24     2                            후라이의 꿈
# 2  2023-09-24     3    Smoke (Prod. Dynamicduo, Padi)
# 3  2023-09-24     4                         Super Shy
# 4  2023-09-24     5  Seven (feat. Latto) - Clean Ver.
#
#                        Artist                 Production  Weekly Views  \
# 0                   AKMU (악뮤)           YG Entertainment    11929992.0
# 1                   AKMU (악뮤)           YG Entertainment    11929992.0
# 2  다이나믹 듀오 (Dynamic Duo), 이영지  Stone Music Entertainment     4473459.0
# 3                    NewJeans                       ADOR    11655019.0
# 4                          정국               BIGHIT MUSIC     4173726.0
#
#          Genre Runtime
# 0      가요 / 댄스   03:00
# 1  가요 / 블루스/포크   03:25
# 2    가요 / 랩/힙합   03:30
# 3      가요 / 댄스   02:35
# 4      가요 / 댄스   03:04

# %%
df2.head()
# Out:
#          date                      Artist     New_Artist
# 0  2023-09-24                   AKMU (악뮤)             악뮤
# 1  2023-09-24  다이나믹 듀오 (Dynamic Duo), 이영지  다이나믹 듀오 , 이영지
# 2  2023-09-24                    NewJeans            뉴진스
# 3  2023-09-24                          정국             정국
# 4  2023-09-24                         전소미            전소미

# %%
df1 = df1.merge(df2[['date', 'Artist', 'New_Artist']], on=['date', 'Artist'], how='left')

# %%
df1.head()
# Out:
#          date  Rank                             Title  \
# 0  2023-09-24     1                          Love Lee
# 1  2023-09-24     2                            후라이의 꿈
# 2  2023-09-24     3    Smoke (Prod. Dynamicduo, Padi)
# 3  2023-09-24     4                         Super Shy
# 4  2023-09-24     5  Seven (feat. Latto) - Clean Ver.
#
#                        Artist                 Production  Weekly Views  \
# 0                   AKMU (악뮤)           YG Entertainment    11929992.0
# 1                   AKMU (악뮤)           YG Entertainment    11929992.0
# 2  다이나믹 듀오 (Dynamic Duo), 이영지  Stone Music Entertainment     4473459.0
# 3                    NewJeans                       ADOR    11655019.0
# 4                          정국               BIGHIT MUSIC     4173726.0
#
#          Genre Runtime     New_Artist
# 0      가요 / 댄스   03:00             악뮤
# 1  가요 / 블루스/포크   03:25             악뮤
# 2    가요 / 랩/힙합   03:30  다이나믹 듀오 , 이영지
# 3      가요 / 댄스   02:35            뉴진스
# ...

# %%
df1.to_csv('circle_chart_data(20240926)_with_new_artist.csv', index=False)
