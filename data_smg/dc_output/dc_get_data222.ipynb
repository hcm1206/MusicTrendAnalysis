# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter # 모듈추가
from requests.packages.urllib3.util.retry import Retry #모듈추가
from bs4 import BeautifulSoup
from datetime import datetime
import time
import os

# CSV 파일 읽기
df = pd.read_csv("dc_(ID,Artist).csv")

#df = df[0:60] # ☆★☆ 이 부분을 각자 수정해주셔야 합니다 ☆★☆
# 결과를 저장할 리스트
results = []

# 결과 파일 경로
output_file = "output.csv"

results_df = pd.DataFrame(columns=["아티스트", "dcinside_ID", "작성일", "조회수", "추천수"])

# 첫 번째 아티스트에 대해 데이터 수집
for index, row in df.iterrows():
    artist_name = row["Artist"]
    artist_id = row["dcinside_ID"]
    print(f'수집 중: 아티스트 "{artist_name}" (ID: {artist_id})')

    page = 1
    scrapying = True

    while scrapying:
        # URL 시도
        urls = [
            f"https://gall.dcinside.com/board/lists/?id={artist_id}&page={page}",
            f"https://gall.dcinside.com/mgallery/board/lists/?id={artist_id}&page={page}",
            f"https://gall.dcinside.com/mini/board/lists/?id={artist_id}&page={page}"
        ]

        data_found = False  # 데이터 발견 여부 초기화

        for url in urls:
            print(f"시도 중: {url}")

            headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
            }

            # Session 객체 생성한 후 Retry 객체를 생성하여 Session 객체에 mount
            session = requests.Session()
            retry = Retry(connect=3, backoff_factor=0.5)
            adapter = HTTPAdapter(max_retries=retry)
            session.mount("http://", adapter)
            session.mount("https://", adapter)

            # response = requests.get(url, headers=headers)
            response = session.get(url, headers=headers)

            
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, "html.parser")
                posts = soup.find_all("tr", class_="ub-content us-post")

                if posts:
                    data_found = True  # 데이터 발견
                    break  # 데이터가 발견되면 반복문 종료
                else:
                    print(f"    {artist_name}의 데이터가 없습니다. 다음 URL로 넘어갑니다.")
            else:
                print(f"{artist_name}의 데이터 가져오기 오류: {response.status_code}")

        if not data_found:
            print(f"    더 이상 게시글이 없습니다. 아티스트: {artist_name}, 페이지: {page}. 수집 종료.")
            break

        for post in posts:
            if post.get("data-type") == "icon_notice":
                print("    공지 게시글 발견: 건너뜁니다.")
                continue

            post_date = post.find("td", class_="gall_date").text.strip()

            if len(post_date) == 5:
                if post_date[2] == '.':
                    if post_date[0] == '0':
                        # 24년 9월의 경우 8일까지만 수집
                        if post_date[1] == '9':
                            if post_date[3] == '0' and post_date[4] == '9':
                                formatted_post_date = f"24.{post_date}"
                            elif post_date[3] == '1' and int(post_date[4]) <= 4:
                                formatted_post_date = f"24.{post_date}"
                            else:
                                print("    작성일 범위 밖: 건너뜁니다.")
                                continue
                        else:
                            formatted_post_date = f"24.{post_date}"
                    else:
                        print("    작성일 범위 밖: 건너뜁니다.")
                        continue
                else:
                    print("    작성일 형식 오류: 건너뜁니다.")
                    continue
            else:
                formatted_post_date = post_date

            formatted_cutoff_date = "24.09.08"

            post_date_dt = datetime.strptime(formatted_post_date, "%y.%m.%d")
            cutoff_date_dt = datetime.strptime(formatted_cutoff_date, "%y.%m.%d")

            if post_date_dt <= cutoff_date_dt:
                print(f"    종료 조건 충족: 작성일 {formatted_post_date}. 수집 완료.")
                scrapying = False
                break
            
            views = post.find("td", class_="gall_count").text.strip()
            recommendations = post.find("td", class_="gall_recommend").text.strip()
            
            results.append({
                "아티스트": artist_name,
                "dcinside_ID": artist_id,
                "작성일": formatted_post_date,
                "조회수": views,
                "추천수": recommendations
            })
            print(f"    수집됨: 작성일 {formatted_post_date}, 조회수 {views}, 추천수 {recommendations}")

        page += 1
        print(f"    다음 페이지: {page}")
        time.sleep(2)

# 수집된 데이터를 DataFrame으로 변환
results_df = pd.concat([results_df, pd.DataFrame(results)], ignore_index=True)

# 결과를 CSV 파일로 저장 (기존 파일에 추가)
results_df.to_csv(output_file, index=False)
print("데이터 수집 완료. 결과를 '1output.csv'로 저장했습니다.")
# Out:
# 수집 중: 아티스트 "AKMU (악뮤)" (ID: akdong)
# 시도 중: https://gall.dcinside.com/board/lists/?id=akdong&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     종료 조건 충족: 작성일 24.07.18. 수집 완료.
#     다음 페이지: 2
# 수집 중: 아티스트 "NewJeans" (ID: newjeans)
# 시도 중: https://gall.dcinside.com/board/lists/?id=newjeans&page=1
#     NewJeans의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=newjeans&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     다음 페이지: 2
# 시도 중: https://gall.dcinside.com/board/lists/?id=newjeans&page=2
#     NewJeans의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=newjeans&page=2
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     다음 페이지: 3
# 시도 중: https://gall.dcinside.com/board/lists/?id=newjeans&page=3
#     NewJeans의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=newjeans&page=3
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     다음 페이지: 4
# 시도 중: https://gall.dcinside.com/board/lists/?id=newjeans&page=4
#     NewJeans의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=newjeans&page=4
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     다음 페이지: 5
# 시도 중: https://gall.dcinside.com/board/lists/?id=newjeans&page=5
#     NewJeans의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=newjeans&page=5
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     종료 조건 충족: 작성일 24.07.24. 수집 완료.
#     다음 페이지: 6
# 수집 중: 아티스트 "정국" (ID: jungkook)
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=1
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 2
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=2
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=2
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 3
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=3
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=3
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 4
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=4
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=4
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 5
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=5
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=5
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 6
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=6
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=6
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 7
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=7
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=7
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 8
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=8
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=8
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 9
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=9
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=9
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 10
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=10
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=10
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 11
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=11
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=11
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 12
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=12
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=12
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 13
# 시도 중: https://gall.dcinside.com/board/lists/?id=jungkook&page=13
#     정국의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=jungkook&page=13
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     수집됨: 작성일 24.09.14, 조회수 102, 추천수 0
#     수집됨: 작성일 24.09.14, 조회수 105, 추천수 0
#     수집됨: 작성일 24.09.14, 조회수 396, 추천수 2
#     수집됨: 작성일 24.09.14, 조회수 86, 추천수 0
#     수집됨: 작성일 24.09.14, 조회수 243, 추천수 4
#     수집됨: 작성일 24.09.14, 조회수 2161, 추천수 80
#     수집됨: 작성일 24.09.14, 조회수 928, 추천수 54
#     수집됨: 작성일 24.09.14, 조회수 1657, 추천수 187
#     수집됨: 작성일 24.09.14, 조회수 144, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수 68, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수 126, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수 204, 추천수 14
#     수집됨: 작성일 24.09.14, 조회수 2216, 추천수 150
#     수집됨: 작성일 24.09.14, 조회수 3462, 추천수 184
#     수집됨: 작성일 24.09.14, 조회수 2524, 추천수 118
#     수집됨: 작성일 24.09.14, 조회수 504, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수 141, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수 144, 추천수 1
#     수집됨: 작성일 24.09.14, 조회수
 추천수 0
#     수집됨: 작성일 24.09.12, 조회수 349, 추천수 30
#     수집됨: 작성일 24.09.12, 조회수 124, 추천수 0
#     수집됨: 작성일 24.09.12, 조회수 86, 추천수 0
#     수집됨: 작성일 24.09.12, 조회수 33, 추천수 0
#     수집됨: 작성일 24.09.12, 조회수 178, 추천수 14
#     수집됨: 작성일 24.09.12, 조회수 148, 추천수 14
#     수집됨: 작성일 24.09.12, 조회수 33, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 291, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 33, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 23, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 24, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 34, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 36, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 26, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 190, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 204, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 174, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 163, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 163, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 171, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 78, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 38, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 22, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 118, 추천수 1
#     수집됨: 작성일 24.09.11, 조회수 26, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 58, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 33, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 38, 추천수 0
#     수집됨: 작성일 24.09.11, 조회수 204, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 194, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 167, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 178, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 174, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 163, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 168, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 183, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 176, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 165, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 136, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 150, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 145, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 19, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 136, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 139, 추천수 0
#     다음 페이지: 7
# 시도 중: https://gall.dcinside.com/board/lists/?id=jeonsomi&page=7
#     수집됨: 작성일 24.09.10, 조회수 135, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 115, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 111, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 102, 추천수 10
#     수집됨: 작성일 24.09.10, 조회수 142, 추천수 11
#     수집됨: 작성일 24.09.10, 조회수 101, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 18, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 83, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 26, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 17, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 19, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 28, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 122, 추천수 13
#     수집됨: 작성일 24.09.10, 조회수 148, 추천수 15
#     수집됨: 작성일 24.09.10, 조회수 75, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 33, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 39, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 116, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 107, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 115, 추천수 0
#     수집됨: 작성일 24.09.10, 조회수 30, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 131, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 133, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 118, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 37, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 80, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 37, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 44, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 40, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 27, 추천수 0
#     수집됨: 작성일 24.09.09, 조회수 164, 추천수 14
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 8
# 시도 중: https://gall.dcinside.com/board/lists/?id=jeonsomi&page=8
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 9
# 시도 중: https://gall.dcinside.com/board/lists/?id=jeonsomi&page=9
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 10
# 시도 중: https://gall.dcinside.com/board/lists/?id=jeonsomi&page=10
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     종료 조건 충족: 작성일 24.08.31. 수집 완료.
#     다음 페이지: 11
# 수집 중: 아티스트 "박재정" (ID: jjp)
# 시도 중: https://gall.dcinside.com/board/lists/?id=jjp&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     수집됨: 작성일 24.09.13, 조회수 1388, 추천수 49
#     수집됨: 작성일 24.09.11, 조회수 1393, 추천수 56
#     작성일 범위 밖: 건너뜁니다.
#     종료 조건 충족: 작성일 24.08.30. 수집 완료.
#     다음 페이지: 2
# 수집 중: 아티스트 "화사(Hwa Sa)" (ID: hwasa)
# 시도 중: https://gall.dcinside.com/board/lists/?id=hwasa&page=1
#     화사(Hwa Sa)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=hwasa&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     수집됨: 작성일 24.09.12, 조회수 349, 추천수 2
#     수집됨: 작성일 24.09.10, 조회수 358, 추천수 1
#     작성일 범위 밖: 건너뜁니다.
#     종료 조건 충족: 작성일 24.07.23. 수집 완료.
#     다음 페이지: 2
# 수집 중: 아티스트 "IVE (아이브)" (ID: starshipgirls)
# 시도 중: https://gall.dcinside.com/board/lists/?id=starshipgirls&page=1
#     IVE (아이브)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=starshipgirls&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 2
# 시도 중: https://gall.dcinside.com/board/lists/?id=starshipgirls&page=2
#     IVE (아이브)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=starshipgirls&page=2
#     작성일 범위 밖: 건너뜁니다.
#     종료 조건 충족: 작성일 24.08.30. 수집 완료.
#     다음 페이지: 3
# 수집 중: 아티스트 "우디(Woody)" (ID: woody0)
# 시도 중: https://gall.dcinside.com/board/lists/?id=woody0&page=1
#     우디(Woody)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=woody0&page=1
#     공지 게시글 발견: 건너뜁니다.
#     종료 조건 충족: 작성일 24.04.09. 수집 완료.
#     다음 페이지: 2
# 수집 중: 아티스트 "STAYC(스테이씨)" (ID: stayc)
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=1
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=1
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     공지 게시글 발견: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
#     작성일 형식 오류: 건너뜁니다.
# ...
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 46
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=46
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=46
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 47
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=47
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=47
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 48
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=48
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=48
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 49
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=49
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=49
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 50
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=50
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=50
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 51
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=51
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=51
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 52
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=52
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=52
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 53
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=53
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=53
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 54
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=54
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=54
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     작성일 범위 밖: 건너뜁니다.
#     다음 페이지: 55
# 시도 중: https://gall.dcinside.com/board/lists/?id=stayc&page=55
#     STAYC(스테이씨)의 데이터가 없습니다. 다음 URL로 넘어갑니다.
# 시도 중: https://gall.dcinside.com/mgallery/board/lists/?id=stayc&page=55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 60
#      56 response = session.get(url, headers=headers)
#      59 if response.status_code == 200:
# ---> 60     soup = BeautifulSoup(response.content, "html.parser")
#      61     posts = soup.find_all("tr", class_="ub-content us-post")
#      63     if posts:
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File c:\Program Files\Python312\Lib\html\parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File c:\Program Files\Python312\Lib\html\parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File c:\Program Files\Python312\Lib\html\parser.py:338, in HTMLParser.parse_starttag(self, i)
#     336     self.handle_startendtag(tag, attrs)
#     337 else:
# --> 338     self.handle_starttag(tag, attrs)
#     339     if tag in self.CDATA_CONTENT_ELEMENTS:
#     340         self.set_cdata_mode(tag)
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\builder\_htmlparser.py:137, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     135 #print("START", name)
#     136 sourceline, sourcepos = self.getpos()
# --> 137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
#     141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#    (...)
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\__init__.py:742, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     724 """Called by the tree builder when a new tag is encountered.
#     725
#     726 :param name: Name of the tag.
#    (...)
#     739 don't call handle_endtag.
#     740 """
#     741 # print("Start tag %s: %s" % (name, attrs))
# --> 742 self.endData()
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
#
# File c:\Program Files\Python312\Lib\site-packages\bs4\__init__.py:617, in BeautifulSoup.endData(self, containerClass)
#     614     return
#     616 containerClass = self.string_container(containerClass)
# --> 617 o = containerClass(current_data)
#     618 self.object_was_parsed(o)
#
# KeyboardInterrupt:
